# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
import scienceplots

plt.style.use(['science', 'ieee', 'grid'])
# plt.style.use(["default"])
plt.rcParams["text.usetex"] = True

# %%
x = np.linspace(0, 2 * np.pi, 500)
y = np.sin(x**2)
z = np.cos(x/2)

fig, ax = plt.subplots(figsize=(7.5,4))
ax.plot(x, y, label=r"$\sin(x)$")
ax.set_xlabel(r"Angle")
ax.plot(x, z, label=r"$\cos(x)$")
ax.set_ylabel(r"Values")
ax.set_xticks([0, np.pi/2, np.pi, np.pi*(3/2), 2*np.pi], [r"0", r"$\frac{\pi}{2}$", r"$\pi$", r"$\frac{3\pi}{2}$", r"$2\pi$"])
ax.legend()
plt.show()

# %%
x = np.linspace(0, 2, 500)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(16/3.5, 9/3.5), layout="constrained")
ax.plot(x, x, label="linear")  # Plot some data on the axes.
ax.plot(x, x**2, label="quadratic")  # Plot more data on the axes...
ax.plot(x, x**3, label="cubic")  # ... and some more.
ax.set_xlabel("x label")  # Add an x-label to the axes.
ax.set_ylabel("y label")  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

plt.show()
