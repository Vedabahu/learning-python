# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../input/AImprove-Contest-1.csv", index_col="index")

# %%
df.head(20)
# Out:
#             price     area  bedrooms  bathrooms  stories  mainroad
# index
# 0      13300000.0   7420.0       4.0        2.0      3.0       1.0
# 1      12250000.0   8960.0       4.0        4.0      4.0       1.0
# 2      12250000.0   9960.0       3.0        2.0      2.0       1.0
# 3      12215000.0   7500.0       4.0        2.0      2.0       1.0
# 4             NaN      NaN       NaN        NaN      NaN       NaN
# 5      11410000.0   7420.0       4.0        1.0      2.0       1.0
# 6      10850000.0   7500.0       3.0        3.0      1.0       1.0
# 7      10150000.0   8580.0       4.0        3.0      4.0       1.0
# 8      10150000.0  16200.0       5.0        3.0      2.0       1.0
# 9       9870000.0   8100.0       4.0        1.0      2.0       1.0
# 10      9800000.0   5750.0       3.0        2.0      4.0       1.0
# 11      9800000.0  13200.0       3.0        1.0      2.0       1.0
# 12      9681000.0   6000.0       4.0        3.0      2.0       1.0
# ...

# %%
df.describe()
# Out:
#               price          area      bedrooms     bathrooms       stories  \
# count  5.500000e+02    550.000000    550.000000    550.000000    550.000000
# mean   1.822905e+09   5082.798182    -28.918182    -30.554545    -30.040000
# std    4.263994e+10   2392.636396    746.326947    746.256715    746.279041
# min   -1.750000e+04 -17500.000000 -17500.000000 -17500.000000 -17500.000000
# 25%    3.430000e+06   3547.500000      2.000000      1.000000      1.000000
# 50%    4.340000e+06   4540.000000      3.000000      1.000000      2.000000
# 75%    5.740000e+06   6360.000000      3.000000      2.000000      2.000000
# max    1.000000e+12  16200.000000      6.000000      4.000000      4.000000
#
#             mainroad
# count     550.000000
# mean     1855.660000
# std     40539.629986
# min    -17500.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max    946912.000000

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 535 entries, 1 to 556
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   price      535 non-null    float64
#  1   area       535 non-null    float64
#  2   bedrooms   535 non-null    float64
#  3   bathrooms  535 non-null    float64
#  4   stories    535 non-null    float64
#  5   mainroad   535 non-null    float64
# dtypes: float64(6)
# memory usage: 29.3 KB

# %%
#pd.set_option("display.max_rows", None)
#df

# %%
df.shape
# Out:
# (565, 6)

# %%
# 1750000 to 13300000
df.drop(df[(df["price"] >= 13300000) | (df["price"] <= 1750000)].index, inplace=True)
df.shape
# Out:
# (556, 6)

# %%
df.dropna(axis=0, how='any', inplace=True)
df.head(10)
# Out:
#             price     area  bedrooms  bathrooms  stories  mainroad
# index
# 1      12250000.0   8960.0       4.0        4.0      4.0       1.0
# 2      12250000.0   9960.0       3.0        2.0      2.0       1.0
# 3      12215000.0   7500.0       4.0        2.0      2.0       1.0
# 5      11410000.0   7420.0       4.0        1.0      2.0       1.0
# 6      10850000.0   7500.0       3.0        3.0      1.0       1.0
# 7      10150000.0   8580.0       4.0        3.0      4.0       1.0
# 8      10150000.0  16200.0       5.0        3.0      2.0       1.0
# 9       9870000.0   8100.0       4.0        1.0      2.0       1.0
# 10      9800000.0   5750.0       3.0        2.0      4.0       1.0
# 11      9800000.0  13200.0       3.0        1.0      2.0       1.0

# %%
df.shape
# Out:
# (541, 6)

# %%
df[ df['bedrooms'] < 0 ].index
df[ df.columns.difference(['mainroad']) ] < 0
# Out:
#         area  bathrooms  bedrooms  price  stories
# index
# 1      False      False     False  False    False
# 2      False      False     False  False    False
# 3      False      False     False  False    False
# 5      False      False     False  False    False
# 6      False      False     False  False    False
# 7      False      False     False  False    False
# 8      False      False     False  False    False
# 9      False      False     False  False    False
# 10     False      False     False  False    False
# 11     False      False     False  False    False
# 12     False      False     False  False    False
# 13     False      False     False  False    False
# 14     False      False     False  False    False
# 15     False      False     False  False    False
# 17     False      False     False  False    False
# 18     False      False     False  False    False
# 19     False      False     False  False    False
# 20     False      False     False  False    False
# ...

# %%
df.drop( df[ (df["bedrooms"] < 0) | (df["bathrooms"] < 0) ].index ,inplace=True)

# %%
type(df["mainroad"])
# Out:
# pandas.core.series.Series

# %%
df["mainroad"].where((df["mainroad"] == 1) | (df["mainroad"] == 0), other=0, inplace=True)
